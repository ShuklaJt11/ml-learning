# %% [markdown]
# # TF Keras Regression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('DATA/kc_house_data.csv')

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.describe().transpose()
# Out:
#                  count          mean           std           min  \
# id             21597.0  4.580474e+09  2.876736e+09  1.000102e+06
# price          21597.0  5.402966e+05  3.673681e+05  7.800000e+04
# bedrooms       21597.0  3.373200e+00  9.262989e-01  1.000000e+00
# bathrooms      21597.0  2.115826e+00  7.689843e-01  5.000000e-01
# sqft_living    21597.0  2.080322e+03  9.181061e+02  3.700000e+02
# sqft_lot       21597.0  1.509941e+04  4.141264e+04  5.200000e+02
# floors         21597.0  1.494096e+00  5.396828e-01  1.000000e+00
# waterfront     21597.0  7.547345e-03  8.654900e-02  0.000000e+00
# view           21597.0  2.342918e-01  7.663898e-01  0.000000e+00
# condition      21597.0  3.409825e+00  6.505456e-01  1.000000e+00
# grade          21597.0  7.657915e+00  1.173200e+00  3.000000e+00
# sqft_above     21597.0  1.788597e+03  8.277598e+02  3.700000e+02
# sqft_basement  21597.0  2.917250e+02  4.426678e+02  0.000000e+00
# ...

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  object
#  2   price          21597 non-null  float64
#  3   bedrooms       21597 non-null  int64
#  4   bathrooms      21597 non-null  float64
#  5   sqft_living    21597 non-null  int64
#  6   sqft_lot       21597 non-null  int64
#  7   floors         21597 non-null  float64
#  8   waterfront     21597 non-null  int64
#  9   view           21597 non-null  int64
#  10  condition      21597 non-null  int64
#  11  grade          21597 non-null  int64
#  12  sqft_above     21597 non-null  int64
#  13  sqft_basement  21597 non-null  int64
#  14  yr_built       21597 non-null  int64
#  15  yr_renovated   21597 non-null  int64
#  16  zipcode        21597 non-null  int64
# ...

# %%
sns.set_style('whitegrid')

# %%
plt.figure(figsize=(12, 7))
sns.distplot(df['price'])

# %%
plt.figure(figsize=(12, 7))
sns.countplot(df['bedrooms'])

# %%
df.corr()
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016772  0.001150   0.005162    -0.012241 -0.131911
# price         -0.016772  1.000000  0.308787   0.525906     0.701917  0.089876
# bedrooms       0.001150  0.308787  1.000000   0.514508     0.578212  0.032471
# bathrooms      0.005162  0.525906  0.514508   1.000000     0.755758  0.088373
# sqft_living   -0.012241  0.701917  0.578212   0.755758     1.000000  0.173453
# sqft_lot      -0.131911  0.089876  0.032471   0.088373     0.173453  1.000000
# floors         0.018608  0.256804  0.177944   0.502582     0.353953 -0.004814
# waterfront    -0.002727  0.266398 -0.006834   0.063744     0.103854  0.021632
# view           0.011536  0.397370  0.080008   0.188386     0.284709  0.074900
# condition     -0.023803  0.036056  0.026496  -0.126479    -0.059445 -0.008830
# grade          0.008188  0.667951  0.356563   0.665838     0.762779  0.114731
# ...

# %%
df.corr()['price'].sort_values()
# Out:
# zipcode         -0.053402
# id              -0.016772
# long             0.022036
# condition        0.036056
# yr_built         0.053953
# sqft_lot15       0.082845
# sqft_lot         0.089876
# yr_renovated     0.126424
# floors           0.256804
# waterfront       0.266398
# lat              0.306692
# bedrooms         0.308787
# sqft_basement    0.323799
# view             0.397370
# bathrooms        0.525906
# sqft_living15    0.585241
# sqft_above       0.605368
# grade            0.667951
# sqft_living      0.701917
# price            1.000000
# Name: price, dtype: float64

# %%
plt.figure(figsize=(12, 7))
sns.scatterplot(x='price', y='sqft_living', data=df)

# %%
plt.figure(figsize=(12, 7))
sns.scatterplot(x='price', y='grade', data=df)

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
sns.pairplot(df, x_vars=['price'], y_vars=['bedrooms', 'bathrooms', 'sqft_living',
       'sqft_lot', 'view', 'condition', 'grade', 'sqft_above', 'sqft_basement', 'sqft_living15', 'sqft_lot15'], height=4, aspect=3)

# %%
plt.figure(figsize=(12, 12))
sns.scatterplot(y='lat', x='long', data=df, hue='price')

# %%
df.sort_values('price', ascending=False).head(20)
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 7245   6762700020  10/13/2014  7700000.0         6       8.00        12050
# 3910   9808700762   6/11/2014  7060000.0         5       4.50        10040
# 9245   9208900037   9/19/2014  6890000.0         6       7.75         9890
# 4407   2470100110    8/4/2014  5570000.0         5       5.75         9200
# 1446   8907500070   4/13/2015  5350000.0         5       5.00         8000
# 1313   7558700030   4/13/2015  5300000.0         6       6.00         7390
# 1162   1247600105  10/20/2014  5110000.0         5       5.25         8010
# 8085   1924059029   6/17/2014  4670000.0         5       6.75         9640
# 2624   7738500731   8/15/2014  4500000.0         5       5.50         6640
# 8629   3835500195   6/18/2014  4490000.0         4       3.00         6430
# 12358  6065300370    5/6/2015  4210000.0         5       6.00         7440
# ...

# %%
bottom_99 = df.sort_values('price', ascending=False).iloc[216:]

# %%
plt.figure(figsize=(12, 12))
sns.scatterplot(y='lat', x='long', data=bottom_99, hue='price', edgecolor=None, alpha=0.2, palette='magma_r')

# %%
plt.figure(figsize=(10, 7))
sns.boxplot(x='waterfront', y='price', data=df)

# %%
df.drop('id', axis=1, inplace=True)

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df['year'] = df['date'].apply(lambda x: x.year)
df['month'] = df['date'].apply(lambda x: x.month)

# %%
df.head()
# Out:
#         date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0 2014-10-13  221900.0         3       1.00         1180      5650     1.0
# 1 2014-12-09  538000.0         3       2.25         2570      7242     2.0
# 2 2015-02-25  180000.0         2       1.00          770     10000     1.0
# 3 2014-12-09  604000.0         4       3.00         1960      5000     1.0
# 4 2015-02-18  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  sqft_basement  yr_built  yr_renovated  \
# 0           0     0          3  ...              0      1955             0
# 1           0     0          3  ...            400      1951          1991
# 2           0     0          3  ...              0      1933             0
# 3           0     0          5  ...            910      1965             0
# 4           0     0          3  ...              0      1987             0
#
# ...

# %%
plt.figure(figsize=(12, 7))
sns.boxplot(x='month', y='price', data=df)

# %%
df.groupby('month').mean()['price']
# Out:
# month
# 1     525963.251534
# 2     508520.051323
# 3     544057.683200
# 4     562215.615074
# 5     550849.746893
# 6     557534.318182
# 7     544892.161013
# 8     536655.212481
# 9     529723.517787
# 10    539439.447228
# 11    522359.903478
# 12    524799.902041
# Name: price, dtype: float64

# %%
plt.figure(figsize=(12, 7))
sns.boxplot(x='year', y='price', data=df)

# %%
df.drop('date', axis=1, inplace=True)

# %%
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  ...  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7  ...              0      1955             0
# 1     0          3      7  ...            400      1951          1991
# 2     0          3      6  ...              0      1933             0
# 3     0          5      7  ...            910      1965             0
# 4     0          3      8  ...              0      1987             0
#
#    zipcode      lat     long  sqft_living15  sqft_lot15  year  month
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   price          21597 non-null  float64
#  1   bedrooms       21597 non-null  int64
#  2   bathrooms      21597 non-null  float64
#  3   sqft_living    21597 non-null  int64
#  4   sqft_lot       21597 non-null  int64
#  5   floors         21597 non-null  float64
#  6   waterfront     21597 non-null  int64
#  7   view           21597 non-null  int64
#  8   condition      21597 non-null  int64
#  9   grade          21597 non-null  int64
#  10  sqft_above     21597 non-null  int64
#  11  sqft_basement  21597 non-null  int64
#  12  yr_built       21597 non-null  int64
#  13  yr_renovated   21597 non-null  int64
#  14  zipcode        21597 non-null  int64
#  15  lat            21597 non-null  float64
#  16  long           21597 non-null  float64
# ...

# %%
df['zipcode'].nunique()
# Out:
# 70

# %%
df.drop('zipcode', axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   price          21597 non-null  float64
#  1   bedrooms       21597 non-null  int64
#  2   bathrooms      21597 non-null  float64
#  3   sqft_living    21597 non-null  int64
#  4   sqft_lot       21597 non-null  int64
#  5   floors         21597 non-null  float64
#  6   waterfront     21597 non-null  int64
#  7   view           21597 non-null  int64
#  8   condition      21597 non-null  int64
#  9   grade          21597 non-null  int64
#  10  sqft_above     21597 non-null  int64
#  11  sqft_basement  21597 non-null  int64
#  12  yr_built       21597 non-null  int64
#  13  yr_renovated   21597 non-null  int64
#  14  lat            21597 non-null  float64
#  15  long           21597 non-null  float64
#  16  sqft_living15  21597 non-null  int64
# ...

# %%
df['yr_renovated'].value_counts()
# Out:
# 0       20683
# 2014       91
# 2013       37
# 2003       36
# 2000       35
#         ...
# 1934        1
# 1959        1
# 1951        1
# 1948        1
# 1944        1
# Name: yr_renovated, Length: 70, dtype: int64

# %%
df['sqft_basement'].value_counts()
# Out:
# 0       13110
# 600       221
# 700       218
# 500       214
# 800       206
#         ...
# 792         1
# 2590        1
# 935         1
# 2390        1
# 248         1
# Name: sqft_basement, Length: 306, dtype: int64

# %%
X = df.drop('price', axis=1).values
y = df['price'].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
X_train.shape
# Out:
# (15117, 19)

# %%
model = Sequential()

model.add(Dense(19, activation='relu'))
model.add(Dense(19, activation='relu'))
model.add(Dense(19, activation='relu'))
model.add(Dense(19, activation='relu'))

model.add(Dense(1))

model.compile(optimizer='adam', loss='mse')

# %%
model.fit(x=X_train, y=y_train, validation_data=(X_test, y_test), batch_size=64, epochs=400)
# Out:
# Train on 15117 samples, validate on 6480 samples
# Epoch 1/400
# 15117/15117 [==============================] - 1s 60us/sample - loss: 429359633412.2675 - val_loss: 417275394275.5555
# Epoch 2/400
# 15117/15117 [==============================] - 0s 22us/sample - loss: 385997286234.2443 - val_loss: 286013966027.5358
# Epoch 3/400
# 15117/15117 [==============================] - 0s 22us/sample - loss: 162119999043.6367 - val_loss: 98784750978.8445
# Epoch 4/400
# 15117/15117 [==============================] - 0s 22us/sample - loss: 98093694516.3278 - val_loss: 95902144557.5111
# Epoch 5/400
# 15117/15117 [==============================] - 0s 21us/sample - loss: 95187397844.4951 - val_loss: 93144616343.0716
# Epoch 6/400
# 15117/15117 [==============================] - 0s 22us/sample - loss: 92199982966.4912 - val_loss: 90260091011.4765
# Epoch 7/400
# 15117/15117 [==============================] - 0s 21us/sample - loss: 89056154627.9966 - val_loss: 87253023433.0074
# Epoch 8/400
# ...

# %%
loss_df = pd.DataFrame(model.history.history)

# %%
loss_df.head()
# Out:
#            loss      val_loss
# 0  4.293596e+11  4.172754e+11
# 1  3.859973e+11  2.860140e+11
# 2  1.621200e+11  9.878475e+10
# 3  9.809369e+10  9.590214e+10
# 4  9.518740e+10  9.314462e+10

# %%
plt.figure(figsize=(12, 7))
sns.lineplot(y=loss_df['loss'], x=loss_df.index, color='blue', label='Loss')
sns.lineplot(y=loss_df['val_loss'], x=loss_df.index, color='orange', label='Val Loss')
plt.legend()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, explained_variance_score

# %%
pred = model.predict(X_test)

# %%
mean_absolute_error(y_test, pred)
# Out:
# 102186.38084611304

# %%
mean_squared_error(y_test, pred)
# Out:
# 28039444589.25232

# %%
np.sqrt(mean_squared_error(y_test, pred))
# Out:
# 167449.82708038943

# %%
explained_variance_score(y_test, pred)
# Out:
# 0.7887370836460355

# %%
single_house = df.drop('price', axis=1).iloc[0]

# %%
single_house = scaler.transform(single_house.values.reshape(-1, 19))

# %%
model.predict(single_house)
# Out:
# array([[277343.4]], dtype=float32)

# %%
df.head(1)
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3        1.0         1180      5650     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
#
#        lat     long  sqft_living15  sqft_lot15  year  month
# 0  47.5112 -122.257           1340        5650  2014     10

# %%
bottom_99['date'] = pd.to_datetime(bottom_99['date'])
bottom_99['year'] = bottom_99['date'].apply(lambda x: x.year)
bottom_99['month'] = bottom_99['date'].apply(lambda x: x.month)
bottom_99.drop('id', axis=1, inplace=True)
bottom_99.drop('date', axis=1, inplace=True)
bottom_99.drop('zipcode', axis=1, inplace=True)
bottom_99.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15', 'year', 'month'],
#       dtype='object')

# %%
X = bottom_99.drop('price', axis=1).values
y = bottom_99['price'].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

model = Sequential()
model.add(Dense(19, activation='relu'))
model.add(Dense(19, activation='relu'))
model.add(Dense(19, activation='relu'))
model.add(Dense(19, activation='relu'))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

model.fit(x=X_train, y=y_train, validation_data=(X_test, y_test), batch_size=64, epochs=400)
# Out:
# Train on 14966 samples, validate on 6415 samples
# Epoch 1/400
# 14966/14966 [==============================] - 1s 57us/sample - loss: 350088437095.4879 - val_loss: 344472144380.5681
# Epoch 2/400
# 14966/14966 [==============================] - 0s 28us/sample - loss: 303320122664.2662 - val_loss: 208184650723.1077
# Epoch 3/400
# 14966/14966 [==============================] - 0s 27us/sample - loss: 100854607605.9762 - val_loss: 54379350006.7417
# Epoch 4/400
# 14966/14966 [==============================] - 0s 29us/sample - loss: 54216963105.5267 - val_loss: 52515413840.0923
# Epoch 5/400
# 14966/14966 [==============================] - 0s 29us/sample - loss: 52466549108.2144 - val_loss: 50726839625.9467
# Epoch 6/400
# 14966/14966 [==============================] - 0s 27us/sample - loss: 50671653119.6237 - val_loss: 48912857318.4998
# Epoch 7/400
# 14966/14966 [==============================] - 0s 27us/sample - loss: 48833959525.7431 - val_loss: 47047876003.3372
# Epoch 8/400
# ...

# %%
loss_df = pd.DataFrame(model.history.history)
plt.figure(figsize=(12, 7))
sns.lineplot(y=loss_df['loss'], x=loss_df.index, color='blue', label='Loss')
sns.lineplot(y=loss_df['val_loss'], x=loss_df.index, color='orange', label='Val Loss')
plt.legend()

# %%
pred = model.predict(X_test)
mean_squared_error(y_test, pred)
# Out:
# 19853052596.954624

# %%
mean_absolute_error(y_test, pred)
# Out:
# 94310.9303938523

# %%
explained_variance_score(y_test, pred)
# Out:
# 0.7531785584934423

# %%
model.predict(single_house)
# Out:
# array([[225276.89]], dtype=float32)
